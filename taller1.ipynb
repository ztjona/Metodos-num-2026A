# %% [markdown]
# # Introducción
# * extensión de python: *.py*
# * extensión de notebook: *.ipynb*

# %% [markdown]
# Símbolo de la terminal:
# Bash
# ```bash
# $ cat
# ```
#
# Command prompt | Powershell
# ```cmd
# > cd
# ```
# Python
# ```python
# >>> print("Hola mundo")
# ```

# %% [markdown]
# ```bash
# git config --global user.name "Pepito Perez"
# git config --global user.email "pepito.perez@epn.edu.ec"
# ```
